# %%
import numpy as np
import tensorflow as tf

# %%
# Datos de entrada y etiquetas
X_train = np.array([[2, 8], [1, 7], [3, 10], [5, 9], [8, 7]], dtype=np.float32)
y_train = np.array([[0], [0], [0], [1], [1]], dtype=np.float32)

# %%
# Definir la arquitectura de la red neuronal
model = tf.keras.Sequential([
    tf.keras.layers.Dense(5, input_shape=(2,), activation='relu'),
    tf.keras.layers.Dense(3, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

# Compilar el modelo
model.compile(loss='binary_crossentropy',
              optimizer='adam', metrics=['accuracy'])

# Entrenar el modelo
model.fit(X_train, y_train, epochs=100, batch_size=1, verbose=1)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 1s 3ms/step - loss: 1.2217 - accuracy: 0.4000
# Epoch 2/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.1978 - accuracy: 0.4000
# Epoch 3/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.1667 - accuracy: 0.4000
# Epoch 4/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.1370 - accuracy: 0.4000
# Epoch 5/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.1246 - accuracy: 0.4000
# Epoch 6/100
# 5/5 [==============================] - 0s 2ms/step - loss: 1.0950 - accuracy: 0.4000
# Epoch 7/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.0652 - accuracy: 0.4000
# Epoch 8/100
# 5/5 [==============================] - 0s 2ms/step - loss: 1.0482 - accuracy: 0.4000
# Epoch 9/100
# 5/5 [==============================] - 0s 3ms/step - loss: 1.0280 - accuracy: 0.4000
# Epoch 10/100
# ...

# %%
# Datos de prueba
X_test = np.array([[4, 8], [6, 7]], dtype=np.float32)

# Realizar predicciones en el conjunto de prueba
predictions = model.predict(X_test)
print(predictions)
# Out:
# 1/1 [==============================] - 0s 110ms/step
# [[0.5867124 ]
#  [0.65822303]]
