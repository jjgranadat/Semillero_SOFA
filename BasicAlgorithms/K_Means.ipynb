# %% [markdown]
# <a href="https://colab.research.google.com/github/jjgranadat/Semillero_SOFA/blob/main/K_Means.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
#Datos
datos = 0
if datos == 0:
    X1 = np.array([0.3, 0.42, 0.5, 0.4, 0.1, 0.35, 0.4, 0.55, 0.24, 0.1, 0.33, 0.45, 0.52, 0.43, 0.05, 0.3, 0.44, 0.5, 0.2, 0.1])
    X2 = np.array([0.14, 0.7, 0.5, 0.3, 0.12, 0.31, 0.5, 0.52, 0.44, 0.2, 0.1, 0.6, 0.42, 0.35, 0.17, 0.36, 0.4, 0.5, 0.4, 0.25])
    #y = np.array([0, 1, 1, 1, 0, 1, 1, 1, 0, 0, 1, 1, 1, 1, 0, 1, 1, 1, 0, 0])
    y = np.array([0, 2, 2, 1, 0, 1, 1, 2, 0, 0, 0, 2, 2, 1, 0, 1, 1, 2, 0, 0])
else:
    tam=100
    Clases=2
    X1 = np.random.rand(1,tam)
    X2 = np.random.rand(1,tam)
    y = np.random.randint(Clases, size=tam)
    X1 = X1[0]
    X2 = X2[0]

# %%
plt.plot(X1, X2, '*')
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.title('Datos')
plt.show()

# %%
fig, ax = plt.subplots()
for g in np.unique(y):
    ix = np.where(y == g)
    ax.scatter(X1[ix], X2[ix], label = g, s = 100)
ax.legend()
plt.xlabel('Característica 1')
plt.ylabel('Característica 2')
plt.title('Datos')
plt.show()

# %%
X = np.transpose(np.array([X1,X2]))

# %%
model = KMeans(n_clusters = 3)
model.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
model.labels_
# Out:
# array([1, 0, 0, 2, 1, 2, 0, 0, 2, 1, 1, 0, 0, 2, 1, 2, 2, 0, 2, 1])

# %%
model.cluster_centers_
# Out:
# array([[0.47714286, 0.53428571],
#        [0.16333333, 0.16333333],
#        [0.33714286, 0.36571429]])

# %%
fig, (ax1, ax2) = plt.subplots(1,2, sharey = True, figsize = (10, 6))
ax1.set_title('k-Means')
ax1.scatter(X[:,0],X[:,1], c=model.labels_)
ax2.set_title('Original')
ax2.scatter(X[:,0],X[:,1], c=y)
