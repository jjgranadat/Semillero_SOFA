# %% [markdown]
# ## Librerías

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import os

from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.cluster import KMeans
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split, GridSearchCV

from scipy.io import loadmat

# %%
os.path.exists("Datos/17.6GHz_spacing")
# Out:
# True

# %% [markdown]
# ## Globales

# %%
def download_file(link):
    # Nombre del archivo
    file = link.split('/')[-1]
    
    # Descarga el archivo si no se ha hecho aún
    # !if ! [[ -f "$file" ]]; then wget $link; fi;

    return file


# Función especial para leer todos los datos con la estructura estudiada
def read_data(folder_rx):
    data = {}

    # Leer la carpeta principal
    for folder in os.listdir(folder_rx):
        # Leer las subcarpetas
        if folder.endswith("spacing"):
            data[folder] = {}
            for file in os.listdir(f"{folder_rx}/{folder}"):
                if file.find("consY") != -1:
                    data_name = file.split("_")[2]
                    if data[folder].get(data_name) == None:
                        data[folder][data_name] = {}
                    mat_file_data = loadmat(f"{folder_rx}/{folder}/{file}")
                    data[folder][data_name] = mat_file_data
    return data

# %% [markdown]
# ## Librería de funciones

# %%
LIB_LINK = "https://raw.githubusercontent.com/jjgranadat/Semillero_SOFA/C%C3%A9sar/sofa.py"
LIB_FILE = download_file(LIB_LINK)
import sofa
# Out:
# No se esperaba [[ en este momento.

# %% [markdown]
# ## Datos experimentales

# %%
# Enlace del archivo (raw)
# link_rx = "https://github.com/jjgranadat/Semillero_SOFA/raw/main/16QAM_3x16GBd_consY250km_00010.mat"
# link_tx = "https://github.com/jjgranadat/Semillero_SOFA/raw/main/2x16QAM_16GBd.mat"

# file_rx = download_file(link_rx)
# X_ch_norm = loadmat(file_rx)
# print(f"Las llaves de X_ch son: {X_ch_norm.keys()}")
# X_ch_norm = X_ch_norm.get("const_Y").flatten()
# X_ch = sofa.mod_norm(X_ch_norm, 10)*X_ch_norm
# print(f"El tamaño de X_ch es: {X_ch_norm.shape}")

# file_tx = download_file(link_tx)
# X_tx_norm = loadmat(file_tx)
# print(f"Las llaves de X_tx son: {X_tx_norm.keys()}")
# X_tx_norm = X_tx_norm.get("Constellation").flatten()[0][1].flatten()
# X_tx = sofa.mod_norm(X_tx_norm, 10)*X_tx_norm
# print(f"El tamaño de X_tx es: {X_tx_norm.shape}")

# %%
file_tx = "Datos/2x16QAM_16GBd.mat"
folder_rx = "Datos"

# Datos transmitidos
X_tx_norm = loadmat(file_tx)
X_tx_norm = X_tx_norm.get("Constellation").flatten()[0][0].flatten()
X_tx = sofa.mod_norm(X_tx_norm, 10)*X_tx_norm

# Leer los datos recibidos
data = read_data(folder_rx)
print(data)
# Out:
# {'16.5Ghz_spacing': {'consY18dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 15:06:25 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[ 0.29724662-0.56954492j, -0.63932383-0.71252797j,
#         -0.16385946+0.1722384j , ...,  0.28743402-0.19787801j,
#         -0.32126164+0.24963581j,  0.25958599+0.29056906j]])}, 'consY19dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 15:02:34 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[ 0.45376741+0.03678953j, -0.49835658+0.16142669j,
#          0.21177422-0.1838741j , ..., -0.31149881+0.668038j  ,
#          0.25656824-0.48250989j,  0.37321772+0.8134094j ]])}, 'consY20dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 15:00:09 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[ 0.61274684+0.09385612j,  0.362316  +0.04350573j,
#          0.45371734-0.41742102j, ...,  0.54160033-0.26926124j,
#          0.0411507 -0.50742743j, -0.6279419 +0.59337195j]])}, 'consY21.5dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 14:57:11 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[-0.05310108+0.16247581j, -0.26875064-0.29139259j,
#         -0.57758707-0.63687906j, ..., -0.667823  -0.79599136j,
#          0.04384813-0.49691149j, -0.33113892-0.15449681j]])}, 'consY23dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 14:55:04 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[-0.28015965+0.60653412j, -0.48845054-0.03112914j,
#          0.06261167-0.5836275j , ..., -0.21819399+0.67348537j,
#          0.53995042+0.13121389j, -0.11874431-0.62236997j]])}, 'consY25dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 14:51:27 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[-0.12372128+0.25953153j,  0.50967815+0.45577972j,
#         -0.2471832 +0.61094564j, ..., -0.59853892+0.58852649j,
#         -0.46944114+0.21258133j,  0.62946136+0.11897369j]])}, 'consY27dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 14:47:48 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[ 0.1532438 +0.1279571j ,  0.39887711-0.52914388j,
#          0.19472142-0.58970617j, ...,  0.05690978-0.57613147j,
#         -0.19442479-0.60219486j, -0.6298223 +0.63574853j]])}, 'consY30dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 14:45:56 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[-0.55090866-0.27487796j, -0.66951602-0.67584903j,
#         -0.18994552-0.49595916j, ..., -0.21486764-0.15240252j,
#         -0.0806958 +0.50780225j, -0.61477716-0.24298617j]])}, 'consY32dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 14:44:18 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[ 0.17833655+0.17019878j, -0.20174098-0.04519528j,
#         -0.60064223+0.25179044j, ..., -0.21783829+0.60741794j,
#          0.57087017+0.52470863j, -0.60607468+0.65193385j]])}, 'consY35dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 14:42:36 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[-0.24131007+0.62603418j, -0.0922305 +0.2315959j ,
#          0.12441028+0.1913353j , ...,  0.21356892+0.16582782j,
#          0.57541376+0.15477075j,  0.4990518 +0.55391871j]])}, 'consY40dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 14:36:56 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[ 0.19501711+0.50822652j,  0.17873773-0.20021341j,
#          0.65704896+0.16678166j, ...,  0.26683853+0.14469028j,
#         -0.30055721-0.52455261j,  0.25109607+0.54361255j]])}}, '17.6GHz_spacing': {'consY18dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 10:35:59 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[-0.197606  +0.23017115j, -0.30944785-0.23057718j,
#         -0.36410279-0.30061807j, ..., -0.1799649 -0.49474924j,
#          0.23262673+0.25299254j,  0.19326253-0.18284251j]])}, 'consY19dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 10:32:44 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[-0.468676  +0.59278446j, -0.10455162-0.26538373j,
#         -0.46566222+0.09748504j, ...,  0.13689391+0.21962204j,
#         -0.12747797+0.14092519j,  0.30764151-0.14024613j]])}, 'consY20dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 10:27:52 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[ 0.19059816-0.65762685j, -0.21971194+0.20658971j,
#         -0.40237958+0.01160795j, ...,  0.59605801-0.45065302j,
#         -0.21978354-0.49501844j, -0.53720972+0.1780943j ]])}, 'consY21.5dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 10:30:35 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[-0.56203511+0.12310478j, -0.12211172-0.20167043j,
#          0.31216727-0.47124024j, ..., -0.41338599-0.04187957j,
#         -0.45904107-0.15161783j,  0.23385076+0.18067871j]])}, 'consY23dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 10:38:12 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[-0.24249694+0.21404862j,  0.24082921+0.47007059j,
#          0.66624668+0.49285686j, ..., -0.64812372-0.37064358j,
#          0.28785154-0.41940584j,  0.52374272-0.46603771j]])}, 'consY25dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 10:21:12 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[-0.20701677-0.2839835j , -0.18320178-0.20109083j,
#         -0.57132033+0.20332048j, ..., -0.47822046+0.58110865j,
#          0.54238872-0.61737954j, -0.39024578+0.59125273j]])}, 'consY27dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 10:41:26 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[-0.0781265 -0.62857111j, -0.65600011+0.1653692j ,
#          0.20223184+0.15312216j, ...,  0.53668605+0.53703563j,
#          0.24824746-0.19382001j,  0.19285281+0.14508154j]])}, 'consY30dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 10:15:32 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[-0.21671193+0.51394175j, -0.19701618-0.67326469j,
#          0.5834436 +0.63920121j, ..., -0.54214239-0.56352315j,
#          0.15476167-0.16737391j,  0.22126017-0.53266013j]])}, 'consY32dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 10:14:02 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[ 0.61055935-0.56869452j,  0.23638549-0.19941241j,
#         -0.16442658-0.17127606j, ...,  0.23462095-0.52102087j,
#         -0.62243613-0.21510901j,  0.27462691+0.17895157j]])}, 'consY35dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 10:11:39 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[-0.60815724-0.47356121j, -0.06929302-0.25365455j,
#          0.20684461-0.1816327j , ..., -0.55876286+0.17145437j,
#          0.59438533-0.61767114j,  0.6313721 +0.51922132j]])}, 'consY40dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 10:10:00 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[ 0.58465984-0.11082485j, -0.18040923-0.20992724j,
#         -0.12411241-0.16416037j, ..., -0.2889156 +0.56380024j,
#          0.21093013+0.5108741j ,  0.62443867+0.47911784j]])}}, '18GHz_spacing': {'consY18dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 16:02:22 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[-0.58209728+0.59017636j, -0.38388381-0.45491689j,
#          0.0672544 -0.60603872j, ...,  0.23618929+0.09815302j,
#          0.16053005+0.27647639j, -0.56806292-0.18656292j]])}, 'consY19dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 16:01:02 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[ 0.6385728 +0.58168551j, -0.16139336+0.58290451j,
#         -0.04835056-0.6786183j , ...,  0.6360418 -0.51227194j,
#          0.43991119-0.53747871j,  0.32890591+0.65449504j]])}, 'consY20dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 15:58:54 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[-0.5074619 -0.09546471j, -0.6069032 +0.60659979j,
#         -0.45134341+0.3642729j , ...,  0.350811  -0.44327676j,
#          0.38271743-0.65815875j, -0.44522816-0.62312168j]])}, 'consY23dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 15:55:31 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[ 0.13584013-0.56007001j,  0.14129473-0.23566737j,
#          0.17569955-0.5207601j , ..., -0.15138128+0.389433j  ,
#          0.56175027+0.55135026j, -0.61809674-0.44934598j]])}, 'consY25dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 15:51:02 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[-0.21331081-0.08651862j,  0.26137053+0.16748288j,
#         -0.20006726-0.28346335j, ..., -0.58717881+0.20085388j,
#          0.59693142-0.12158928j,  0.5229322 +0.63353958j]])}, 'consY27dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 15:47:02 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[ 0.18780133-0.17487523j, -0.21253715+0.57987747j,
#         -0.12282521-0.12591441j, ...,  0.29452705-0.09517103j,
#          0.49239706-0.6902923j ,  0.52308436+0.10962746j]])}, 'consY30dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 15:43:01 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[-0.64172444+0.30641402j,  0.63306149-0.54517192j,
#         -0.53449468-0.49271913j, ..., -0.21159424-0.22900457j,
#          0.27881871-0.56930409j, -0.26800105+0.48016977j]])}, 'consY32dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 15:41:14 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[ 0.23000435+0.53811719j,  0.20298226-0.23615778j,
#          0.18983846-0.48684451j, ..., -0.52264203+0.20576425j,
#         -0.58241359-0.61309154j,  0.47583795-0.15272906j]])}, 'consY35dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 15:35:57 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[ 0.63339496+0.60160783j, -0.5825867 +0.57128845j,
#          0.598274  -0.18637474j, ..., -0.57844613-0.3072039j ,
#         -0.60062373-0.23364092j, -0.53958359-0.19163374j]])}, 'consY40dB': {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jan 07 15:33:42 2015', '__version__': '1.0', '__globals__': [], 'const_Y': array([[0.20135112+0.52364607j, 0.2423822 +0.15009323j,
#         0.21140107+0.18724878j, ..., 0.5281173 +0.57056732j,
#         0.54315784-0.11896414j, 0.18506045+0.19547621j]])}}}

# %% [markdown]
# ## Demodulación usando KMeans

# %%
spacing = "17.6GHz_spacing"

ber = {}

plt.figure(figsize = (16, 16))

for i, snr in enumerate(data[spacing]):
    # Extraer información
    X_ch_norm = data[spacing][snr].get("const_Y").flatten()
    X_ch = sofa.mod_norm(X_ch_norm, 10)*X_ch_norm
    Xr_ch = X_ch.real
    Xi_ch = X_ch.imag
    Xr_tx = X_tx.real
    Xi_tx = X_tx.imag

    # Demodular
    X = X_ch.T
    signals = []
    kmeans_ber = []
    trad_ber = []
    knn_ber = []
    
    for ph in range(4):
        # Constelación recibida rotada
        rotated_X = X_ch*np.exp(ph*1j*np.pi/2)
        # Sincronización de las señales
        synced_X_tx = sofa.sync_signals(X_tx, rotated_X)
        # Se demodula la señal transmitida
        y = sofa.demodulate(synced_X_tx, sofa.MOD_DICT)
        # Demodulación de la recibida rotada
        kmeans_model = sofa.demodulate_kmeans(rotated_X, sofa.MOD_DICT)
        kmeans = kmeans_model.predict(list(zip(rotated_X.real, rotated_X.imag)))
        trad = sofa.demodulate(rotated_X, sofa.MOD_DICT)

        #KNN----------------------------------------------------------
        knn = sofa.demodulate_knn(rotated_X,y,5)

        # BER de la demodulación con respecto a la transmitida desplazada
        kmeans_ber.append(sofa.bit_error_rate(kmeans, y)[0])
        trad_ber.append(sofa.bit_error_rate(trad, y)[0])
        knn_ber.append(sofa.bit_error_rate(knn,y)[0])
        print("Rotada iteració ", ph , ": ", rotated_X)
        signals.append((rotated_X, synced_X_tx, y, kmeans_model))
       
    #================================================================

    true_index = np.where(kmeans_ber == np.amin(kmeans_ber))[0][0]
    rotated_X, synced_X_tx, y, kmeans_model = signals[true_index]
    print("Constelación final: ",rotated_X)
    ber[snr] = {"kmeans": kmeans_ber[true_index],
                "trad": trad_ber[true_index],
                "knn": knn_ber[true_index]}
    print(ber)

    # Probar la correlación con los datos sin demodular
    # Probar girando 90° la constelación recibida
    
    # Graficar
    plt.subplot(4, 3, i + 1)

    # Constelación transmitida
    plt.scatter(Xr_ch, Xi_ch, c = kmeans_model.labels_, marker = 'o')    
    A_mc = np.array([(x.real, x.imag) for x in list(sofa.MOD_DICT.values())])    
    plt.scatter(A_mc[:,0], A_mc[:,1],
                s = 100, label = "Centroides iniciales",
                marker = 'o', color = "red")    
    plt.scatter(kmeans_model.cluster_centers_[:, 0], kmeans_model.cluster_centers_[:, 1],
                s = 100, label = "Centroides finales",
                marker = 'o', color = "green")
    
    plt.title(f"Espaciamiento: {spacing.split('_')[0]}, SNR: {snr[5:]}")
    plt.legend(loc="upper right", prop={'size':9})
    plt.xlabel("I")
    plt.ylabel("Q")
    plt.grid(True)
    # Mensaje para saber que se progresa
    print(f"SNR {snr[5:]} terminado.")
plt.show()
# Out:
# Rotada iteració  0 :  [-1.08402187+1.26266694j -1.697561  -1.26489433j -1.99738568-1.6491228j
#  ... -0.98724681-2.71408255j  1.27613769+1.38785994j
#   1.06019457-1.00303273j]
# Rotada iteració  1 :  [-1.26266694-1.08402187j  1.26489433-1.697561j    1.6491228 -1.99738568j
#  ...  2.71408255-0.98724681j -1.38785994+1.27613769j
#   1.00303273+1.06019457j]
# Rotada iteració  2 :  [ 1.08402187-1.26266694j  1.697561  +1.26489433j  1.99738568+1.6491228j
#  ...  0.98724681+2.71408255j -1.27613769-1.38785994j
#  -1.06019457+1.00303273j]
# Rotada iteració  3 :  [ 1.26266694+1.08402187j -1.26489433+1.697561j   -1.6491228 +1.99738568j
#  ... -2.71408255+0.98724681j  1.38785994-1.27613769j
#  -1.00303273-1.06019457j]
# Constelación final:  [ 1.08402187-1.26266694j  1.697561  +1.26489433j  1.99738568+1.6491228j
#  ...  0.98724681+2.71408255j -1.27613769-1.38785994j
#  -1.06019457+1.00303273j]
# {'consY18dB': {'kmeans': 0.048415913433274546, 'trad': 0.05048500881834215, 'knn': 0.04566477439741329}}
# SNR 18dB terminado.
# Rotada iteració  0 :  [-2.53115352+3.20141949j -0.5646464 -1.43324379j -2.51487719+0.5264823j
#  ...  0.73931564+1.18610105j -0.68846348+0.76108716j
#   1.66146313-0.75741982j]
# Rotada iteració  1 :  [-3.20141949-2.53115352j  1.43324379-0.5646464j  -0.5264823 -2.51487719j
#  ... -1.18610105+0.73931564j -0.76108716-0.68846348j
#   0.75741982+1.66146313j]
# Rotada iteració  2 :  [ 2.53115352-3.20141949j  0.5646464 +1.43324379j  2.51487719-0.5264823j
#  ... -0.73931564-1.18610105j  0.68846348-0.76108716j
#  -1.66146313+0.75741982j]
# Rotada iteració  3 :  [ 3.20141949+2.53115352j -1.43324379+0.5646464j   0.5264823 +2.51487719j
#  ...  1.18610105-0.73931564j  0.76108716+0.68846348j
#  -0.75741982-1.66146313j]
# Constelación final:  [-3.20141949-2.53115352j  1.43324379-0.5646464j  -0.5264823 -2.51487719j
#  ... -1.18610105+0.73931564j -0.76108716-0.68846348j
#   0.75741982+1.66146313j]
# {'consY18dB': {'kmeans': 0.048415913433274546, 'trad': 0.05048500881834215, 'knn': 0.04566477439741329}, 'consY19dB': {'kmeans': 0.0343777557319224, 'trad': 0.036304471634332744, 'knn': 0.0324211860670194}}
# SNR 19dB terminado.
# Rotada iteració  0 :  [ 1.01418302-3.49926767j -1.16909901+1.09927488j -2.14108331+0.0617665j
#  ...  3.1716566 -2.39794884j -1.16947997-2.63401964j
#  -2.85852171+0.94764929j]
# Rotada iteració  1 :  [ 3.49926767+1.01418302j -1.09927488-1.16909901j -0.0617665 -2.14108331j
#  ...  2.39794884+3.1716566j   2.63401964-1.16947997j
#  -0.94764929-2.85852171j]
# Rotada iteració  2 :  [-1.01418302+3.49926767j  1.16909901-1.09927488j  2.14108331-0.0617665j
#  ... -3.1716566 +2.39794884j  1.16947997+2.63401964j
#   2.85852171-0.94764929j]
# Rotada iteració  3 :  [-3.49926767-1.01418302j  1.09927488+1.16909901j  0.0617665 +2.14108331j
#  ... -2.39794884-3.1716566j  -2.63401964+1.16947997j
#   0.94764929+2.85852171j]
# Constelación final:  [-1.01418302+3.49926767j  1.16909901-1.09927488j  2.14108331-0.0617665j
#  ... -3.1716566 +2.39794884j  1.16947997+2.63401964j
#   2.85852171-0.94764929j]
# {'consY18dB': {'kmeans': 0.048415913433274546, 'trad': 0.05048500881834215, 'knn': 0.04566477439741329}, 'consY19dB': {'kmeans': 0.0343777557319224, 'trad': 0.036304471634332744, 'knn': 0.0324211860670194}, 'consY20dB': {'kmeans': 0.02034648736037625, 'trad': 0.02221579218106996, 'knn': 0.019239601704879483}}
# SNR 20dB terminado.
# Rotada iteració  0 :  [-2.95902714+0.64812747j -0.64289915-1.06176331j  1.64351192-2.48100628j
#  ... -2.1764127 -0.22048938j -2.41677957-0.79824422j
#   1.23118775+0.95124521j]
# Rotada iteració  1 :  [-0.64812747-2.95902714j  1.06176331-0.64289915j  2.48100628+1.64351192j
#  ...  0.22048938-2.1764127j   0.79824422-2.41677957j
#  -0.95124521+1.23118775j]
# Rotada iteració  2 :  [ 2.95902714-0.64812747j  0.64289915+1.06176331j -1.64351192+2.48100628j
#  ...  2.1764127 +0.22048938j  2.41677957+0.79824422j
#  -1.23118775-0.95124521j]
# Rotada iteració  3 :  [ 0.64812747+2.95902714j -1.06176331+0.64289915j -2.48100628-1.64351192j
#  ... -0.22048938+2.1764127j  -0.79824422+2.41677957j
#   0.95124521-1.23118775j]
# Constelación final:  [-0.64812747-2.95902714j  1.06176331-0.64289915j  2.48100628+1.64351192j
#  ...  0.22048938-2.1764127j   0.79824422-2.41677957j
#  -0.95124521+1.23118775j]
# {'consY18dB': {'kmeans': 0.048415913433274546, 'trad': 0.05048500881834215, 'knn': 0.04566477439741329}, 'consY19dB': {'kmeans': 0.0343777557319224, 'trad': 0.036304471634332744, 'knn': 0.0324211860670194}, 'consY20dB': {'kmeans': 0.02034648736037625, 'trad': 0.02221579218106996, 'knn': 0.019239601704879483}, 'consY21.5dB': {'kmeans': 0.010281176513815403, 'trad': 0.01184046149323927, 'knn': 0.009553203997648443}}
# SNR 21.5dB terminado.
# Rotada iteració  0 :  [-1.2679536 +1.11920469j  1.25923343+2.45787715j  3.48363101+2.57702063j
#  ... -3.38887073-1.93799909j  1.50510102-2.19296429j
#   2.73851476-2.43679027j]
# Rotada iteració  1 :  [-1.11920469-1.2679536j  -2.45787715+1.25923343j -2.57702063+3.48363101j
#  ...  1.93799909-3.38887073j  2.19296429+1.50510102j
#   2.43679027+2.73851476j]
# Rotada iteració  2 :  [ 1.2679536 -1.11920469j -1.25923343-2.45787715j -3.48363101-2.57702063j
#  ...  3.38887073+1.93799909j -1.50510102+2.19296429j
#  -2.73851476+2.43679027j]
# Rotada iteració  3 :  [ 1.11920469+1.2679536j   2.45787715-1.25923343j  2.57702063-3.48363101j
#  ... -1.93799909+3.38887073j -2.19296429-1.50510102j
#  -2.43679027-2.73851476j]
# Constelación final:  [ 1.11920469+1.2679536j   2.45787715-1.25923343j  2.57702063-3.48363101j
#  ... -1.93799909+3.38887073j -2.19296429-1.50510102j
#  -2.43679027-2.73851476j]
# {'consY18dB': {'kmeans': 0.048415913433274546, 'trad': 0.05048500881834215, 'knn': 0.04566477439741329}, 'consY19dB': {'kmeans': 0.0343777557319224, 'trad': 0.036304471634332744, 'knn': 0.0324211860670194}, 'consY20dB': {'kmeans': 0.02034648736037625, 'trad': 0.02221579218106996, 'knn': 0.019239601704879483}, 'consY21.5dB': {'kmeans': 0.010281176513815403, 'trad': 0.01184046149323927, 'knn': 0.009553203997648443}, 'consY23dB': {'kmeans': 0.005024617871840094, 'trad': 0.006248622134038801, 'knn': 0.004739858906525573}}
# SNR 23dB terminado.
# Rotada iteració  0 :  [-1.07639952-1.47659392j -0.95257164-1.04558715j -2.9706237 +1.05718037j
#  ... -2.48654379+3.0215188j   2.82019156-3.21011207j
#  -2.02911275+3.07426375j]
# Rotada iteració  1 :  [ 1.47659392-1.07639952j  1.04558715-0.95257164j -1.05718037-2.9706237j
#  ... -3.0215188 -2.48654379j  3.21011207+2.82019156j
#  -3.07426375-2.02911275j]
# Rotada iteració  2 :  [ 1.07639952+1.47659392j  0.95257164+1.04558715j  2.9706237 -1.05718037j
#  ...  2.48654379-3.0215188j  -2.82019156+3.21011207j
#   2.02911275-3.07426375j]
# Rotada iteració  3 :  [-1.47659392+1.07639952j -1.04558715+0.95257164j  1.05718037+2.9706237j
#  ...  3.0215188 +2.48654379j -3.21011207-2.82019156j
#   3.07426375+2.02911275j]
# Constelación final:  [ 1.47659392-1.07639952j  1.04558715-0.95257164j -1.05718037-2.9706237j
#  ... -3.0215188 -2.48654379j  3.21011207+2.82019156j
#  -3.07426375-2.02911275j]
# {'consY18dB': {'kmeans': 0.048415913433274546, 'trad': 0.05048500881834215, 'knn': 0.04566477439741329}, 'consY19dB': {'kmeans': 0.0343777557319224, 'trad': 0.036304471634332744, 'knn': 0.0324211860670194}, 'consY20dB': {'kmeans': 0.02034648736037625, 'trad': 0.02221579218106996, 'knn': 0.019239601704879483}, 'consY21.5dB': {'kmeans': 0.010281176513815403, 'trad': 0.01184046149323927, 'knn': 0.009553203997648443}, 'consY23dB': {'kmeans': 0.005024617871840094, 'trad': 0.006248622134038801, 'knn': 0.004739858906525573}, 'consY25dB': {'kmeans': 0.001506466784244562, 'trad': 0.0019910163139329807, 'knn': 0.0014628343621399178}}
# SNR 25dB terminado.
# Rotada iteració  0 :  [-0.40494973-3.25804565j -3.40021719+0.85715109j  1.04821959+0.7936715j
#  ...  2.78178172+2.78359372j  1.28673039-1.00461895j
#   0.9996057 +0.75199489j]
# Rotada iteració  1 :  [ 3.25804565-0.40494973j -0.85715109-3.40021719j -0.7936715 +1.04821959j
#  ... -2.78359372+2.78178172j  1.00461895+1.28673039j
#  -0.75199489+0.9996057j ]
# Rotada iteració  2 :  [ 0.40494973+3.25804565j  3.40021719-0.85715109j -1.04821959-0.7936715j
#  ... -2.78178172-2.78359372j -1.28673039+1.00461895j
#  -0.9996057 -0.75199489j]
# Rotada iteració  3 :  [-3.25804565+0.40494973j  0.85715109+3.40021719j  0.7936715 -1.04821959j
#  ...  2.78359372-2.78178172j -1.00461895-1.28673039j
#   0.75199489-0.9996057j ]
# Constelación final:  [ 0.40494973+3.25804565j  3.40021719-0.85715109j -1.04821959-0.7936715j
#  ... -2.78178172-2.78359372j -1.28673039+1.00461895j
#  -0.9996057 -0.75199489j]
# {'consY18dB': {'kmeans': 0.048415913433274546, 'trad': 0.05048500881834215, 'knn': 0.04566477439741329}, 'consY19dB': {'kmeans': 0.0343777557319224, 'trad': 0.036304471634332744, 'knn': 0.0324211860670194}, 'consY20dB': {'kmeans': 0.02034648736037625, 'trad': 0.02221579218106996, 'knn': 0.019239601704879483}, 'consY21.5dB': {'kmeans': 0.010281176513815403, 'trad': 0.01184046149323927, 'knn': 0.009553203997648443}, 'consY23dB': {'kmeans': 0.005024617871840094, 'trad': 0.006248622134038801, 'knn': 0.004739858906525573}, 'consY25dB': {'kmeans': 0.001506466784244562, 'trad': 0.0019910163139329807, 'knn': 0.0014628343621399178}, 'consY27dB': {'kmeans': 0.0005924823633156966, 'trad': 0.0008910199882422105, 'knn': 0.0005626286008230453}}
# SNR 27dB terminado.
# Rotada iteració  0 :  [-1.12115705+2.65887267j -1.0192613 -3.48312833j  3.0184398 +3.30690127j
#  ... -2.80476842-2.91538153j  0.80065798-0.8659073j
#   1.14468733-2.755712j  ]
# Rotada iteració  1 :  [-2.65887267-1.12115705j  3.48312833-1.0192613j  -3.30690127+3.0184398j
#  ...  2.91538153-2.80476842j  0.8659073 +0.80065798j
#   2.755712  +1.14468733j]
# Rotada iteració  2 :  [ 1.12115705-2.65887267j  1.0192613 +3.48312833j -3.0184398 -3.30690127j
#  ...  2.80476842+2.91538153j -0.80065798+0.8659073j
#  -1.14468733+2.755712j  ]
# Rotada iteració  3 :  [ 2.65887267+1.12115705j -3.48312833+1.0192613j   3.30690127-3.0184398j
#  ... -2.91538153+2.80476842j -0.8659073 -0.80065798j
#  -2.755712  -1.14468733j]
# Constelación final:  [-2.65887267-1.12115705j  3.48312833-1.0192613j  -3.30690127+3.0184398j
#  ...  2.91538153-2.80476842j  0.8659073 +0.80065798j
#   2.755712  +1.14468733j]
# {'consY18dB': {'kmeans': 0.048415913433274546, 'trad': 0.05048500881834215, 'knn': 0.04566477439741329}, 'consY19dB': {'kmeans': 0.0343777557319224, 'trad': 0.036304471634332744, 'knn': 0.0324211860670194}, 'consY20dB': {'kmeans': 0.02034648736037625, 'trad': 0.02221579218106996, 'knn': 0.019239601704879483}, 'consY21.5dB': {'kmeans': 0.010281176513815403, 'trad': 0.01184046149323927, 'knn': 0.009553203997648443}, 'consY23dB': {'kmeans': 0.005024617871840094, 'trad': 0.006248622134038801, 'knn': 0.004739858906525573}, 'consY25dB': {'kmeans': 0.001506466784244562, 'trad': 0.0019910163139329807, 'knn': 0.0014628343621399178}, 'consY27dB': {'kmeans': 0.0005924823633156966, 'trad': 0.0008910199882422105, 'knn': 0.0005626286008230453}, 'consY30dB': {'kmeans': 0.00023653365667254556, 'trad': 0.0003926917989417989, 'knn': 0.00018601190476190475}}
# SNR 30dB terminado.
# Rotada iteració  0 :  [ 3.15427501-2.93799268j  1.22121597-1.03020549j -0.84946147-0.88484729j
#  ...  1.2121    -2.69170083j -3.21563292-1.11129734j
#   1.41877901+0.92450058j]
# Rotada iteració  1 :  [ 2.93799268+3.15427501j  1.03020549+1.22121597j  0.88484729-0.84946147j
#  ...  2.69170083+1.2121j      1.11129734-3.21563292j
#  -0.92450058+1.41877901j]
# Rotada iteració  2 :  [-3.15427501+2.93799268j -1.22121597+1.03020549j  0.84946147+0.88484729j
#  ... -1.2121    +2.69170083j  3.21563292+1.11129734j
#  -1.41877901-0.92450058j]
# Rotada iteració  3 :  [-2.93799268-3.15427501j -1.03020549-1.22121597j -0.88484729+0.84946147j
#  ... -2.69170083-1.2121j     -1.11129734+3.21563292j
#   0.92450058-1.41877901j]
# Constelación final:  [ 3.15427501-2.93799268j  1.22121597-1.03020549j -0.84946147-0.88484729j
#  ...  1.2121    -2.69170083j -3.21563292-1.11129734j
#   1.41877901+0.92450058j]
# {'consY18dB': {'kmeans': 0.048415913433274546, 'trad': 0.05048500881834215, 'knn': 0.04566477439741329}, 'consY19dB': {'kmeans': 0.0343777557319224, 'trad': 0.036304471634332744, 'knn': 0.0324211860670194}, 'consY20dB': {'kmeans': 0.02034648736037625, 'trad': 0.02221579218106996, 'knn': 0.019239601704879483}, 'consY21.5dB': {'kmeans': 0.010281176513815403, 'trad': 0.01184046149323927, 'knn': 0.009553203997648443}, 'consY23dB': {'kmeans': 0.005024617871840094, 'trad': 0.006248622134038801, 'knn': 0.004739858906525573}, 'consY25dB': {'kmeans': 0.001506466784244562, 'trad': 0.0019910163139329807, 'knn': 0.0014628343621399178}, 'consY27dB': {'kmeans': 0.0005924823633156966, 'trad': 0.0008910199882422105, 'knn': 0.0005626286008230453}, 'consY30dB': {'kmeans': 0.00023653365667254556, 'trad': 0.0003926917989417989, 'knn': 0.00018601190476190475}, 'consY32dB': {'kmeans': 0.00018830834803057025, 'trad': 0.00023883009994121106, 'knn': 0.0001286008230452675}}
# SNR 32dB terminado.
# Rotada iteració  0 :  [-3.13868226-2.44403597j -0.35761931-1.30910395j  1.06751919-0.93740124j
#  ... -2.88375931+0.88487113j  3.06760583-3.18778323j
#   3.25849352+2.67968651j]
# Rotada iteració  1 :  [ 2.44403597-3.13868226j  1.30910395-0.35761931j  0.93740124+1.06751919j
#  ... -0.88487113-2.88375931j  3.18778323+3.06760583j
#  -2.67968651+3.25849352j]
# Rotada iteració  2 :  [ 3.13868226+2.44403597j  0.35761931+1.30910395j -1.06751919+0.93740124j
#  ...  2.88375931-0.88487113j -3.06760583+3.18778323j
#  -3.25849352-2.67968651j]
# Rotada iteració  3 :  [-2.44403597+3.13868226j -1.30910395+0.35761931j -0.93740124-1.06751919j
#  ...  0.88487113+2.88375931j -3.18778323-3.06760583j
#   2.67968651-3.25849352j]
# Constelación final:  [-3.13868226-2.44403597j -0.35761931-1.30910395j  1.06751919-0.93740124j
#  ... -2.88375931+0.88487113j  3.06760583-3.18778323j
#   3.25849352+2.67968651j]
# {'consY18dB': {'kmeans': 0.048415913433274546, 'trad': 0.05048500881834215, 'knn': 0.04566477439741329}, 'consY19dB': {'kmeans': 0.0343777557319224, 'trad': 0.036304471634332744, 'knn': 0.0324211860670194}, 'consY20dB': {'kmeans': 0.02034648736037625, 'trad': 0.02221579218106996, 'knn': 0.019239601704879483}, 'consY21.5dB': {'kmeans': 0.010281176513815403, 'trad': 0.01184046149323927, 'knn': 0.009553203997648443}, 'consY23dB': {'kmeans': 0.005024617871840094, 'trad': 0.006248622134038801, 'knn': 0.004739858906525573}, 'consY25dB': {'kmeans': 0.001506466784244562, 'trad': 0.0019910163139329807, 'knn': 0.0014628343621399178}, 'consY27dB': {'kmeans': 0.0005924823633156966, 'trad': 0.0008910199882422105, 'knn': 0.0005626286008230453}, 'consY30dB': {'kmeans': 0.00023653365667254556, 'trad': 0.0003926917989417989, 'knn': 0.00018601190476190475}, 'consY32dB': {'kmeans': 0.00018830834803057025, 'trad': 0.00023883009994121106, 'knn': 0.0001286008230452675}, 'consY35dB': {'kmeans': 9.645061728395061e-05, 'trad': 0.00017912257495590828, 'knn': 6.200396825396825e-05}}
# SNR 35dB terminado.
# Rotada iteració  0 :  [ 3.01485283-0.57147866j -0.93029698-1.08250933j -0.63999717-0.84650822j
#  ... -1.48982016+2.9072884j   1.08768086+2.6343698j
#   3.21997608+2.47061571j]
# Rotada iteració  1 :  [ 0.57147866+3.01485283j  1.08250933-0.93029698j  0.84650822-0.63999717j
#  ... -2.9072884 -1.48982016j -2.6343698 +1.08768086j
#  -2.47061571+3.21997608j]
# Rotada iteració  2 :  [-3.01485283+0.57147866j  0.93029698+1.08250933j  0.63999717+0.84650822j
#  ...  1.48982016-2.9072884j  -1.08768086-2.6343698j
#  -3.21997608-2.47061571j]
# Rotada iteració  3 :  [-0.57147866-3.01485283j -1.08250933+0.93029698j -0.84650822+0.63999717j
#  ...  2.9072884 +1.48982016j  2.6343698 -1.08768086j
#   2.47061571-3.21997608j]
# Constelación final:  [ 3.01485283-0.57147866j -0.93029698-1.08250933j -0.63999717-0.84650822j
#  ... -1.48982016+2.9072884j   1.08768086+2.6343698j
#   3.21997608+2.47061571j]
# {'consY18dB': {'kmeans': 0.048415913433274546, 'trad': 0.05048500881834215, 'knn': 0.04566477439741329}, 'consY19dB': {'kmeans': 0.0343777557319224, 'trad': 0.036304471634332744, 'knn': 0.0324211860670194}, 'consY20dB': {'kmeans': 0.02034648736037625, 'trad': 0.02221579218106996, 'knn': 0.019239601704879483}, 'consY21.5dB': {'kmeans': 0.010281176513815403, 'trad': 0.01184046149323927, 'knn': 0.009553203997648443}, 'consY23dB': {'kmeans': 0.005024617871840094, 'trad': 0.006248622134038801, 'knn': 0.004739858906525573}, 'consY25dB': {'kmeans': 0.001506466784244562, 'trad': 0.0019910163139329807, 'knn': 0.0014628343621399178}, 'consY27dB': {'kmeans': 0.0005924823633156966, 'trad': 0.0008910199882422105, 'knn': 0.0005626286008230453}, 'consY30dB': {'kmeans': 0.00023653365667254556, 'trad': 0.0003926917989417989, 'knn': 0.00018601190476190475}, 'consY32dB': {'kmeans': 0.00018830834803057025, 'trad': 0.00023883009994121106, 'knn': 0.0001286008230452675}, 'consY35dB': {'kmeans': 9.645061728395061e-05, 'trad': 0.00017912257495590828, 'knn': 6.200396825396825e-05}, 'consY40dB': {'kmeans': 0.0001010435038212816, 'trad': 0.000126304379776602, 'knn': 3.903953556731335e-05}}
# SNR 40dB terminado.

# %%
snr = [18, 19, 20, 21.5, 23, 25, 27, 30, 32, 35, 40]
kBER = [ber.get(f"consY{snr_i}dB").get("kmeans") for snr_i in snr]
tBER = [ber.get(f"consY{snr_i}dB").get("trad") for snr_i in snr]
knnBER = [ber.get(f"consY{snr_i}dB").get("knn") for snr_i in snr]
plt.figure(figsize = (10, 10))
plt.semilogy(snr, kBER, marker = "x", label = "K-Means")
plt.semilogy(snr, tBER, marker = "o", label = "Tradicional")
plt.semilogy(snr, knnBER, marker = "^", label = "Knn")

plt.xlabel("OSNR (dB)")
plt.ylabel("BER")
plt.title(spacing)
plt.grid()
plt.legend(loc = "upper right")
plt.show()

# %% [markdown]
# ## Comparando vecinos KNN

# %%
spacing = "18GHz_spacing"
ber = {}
knn_nei = {}
vecinos = [3,5,7,9,13,15]
l_snr = []
for i, snr in enumerate(data[spacing]):
    l_snr.append(snr[5:-2])
    # Extraer información
    X_ch_norm = data[spacing][snr].get("const_Y").flatten()
    X_ch = sofa.mod_norm(X_ch_norm, 10)*X_ch_norm
    Xr_ch = X_ch.real
    Xi_ch = X_ch.imag
    Xr_tx = X_tx.real
    Xi_tx = X_tx.imag

    # Demodular
    X = X_ch.T
    signals = []
    kmeans_ber = []
    trad_ber = []
    knn_ber = []
    
    for ph in range(4):
        # Constelación recibida rotada
        rotated_X = X_ch*np.exp(ph*1j*np.pi/2)
        # Sincronización de las señales
        synced_X_tx = sofa.sync_signals(X_tx, rotated_X)
        # Se demodula la señal transmitida
        y = sofa.demodulate(synced_X_tx, sofa.MOD_DICT)
        # Demodulación de la recibida rotada
        kmeans_model = sofa.demodulate_kmeans(rotated_X, sofa.MOD_DICT)
        kmeans = kmeans_model.predict(list(zip(rotated_X.real, rotated_X.imag)))
        trad = sofa.demodulate(rotated_X, sofa.MOD_DICT)

        #KNN----------------------------------------------------------
        

        # BER de la demodulación con respecto a la transmitida desplazada
        kmeans_ber.append(sofa.bit_error_rate(kmeans, y)[0])
        trad_ber.append(sofa.bit_error_rate(trad, y)[0])
        
        #print("Rotada iteració ", ph , ": ", rotated_X)
        signals.append((rotated_X, synced_X_tx, y, kmeans_model))
       
    #================================================================

    true_index = np.where(kmeans_ber == np.amin(kmeans_ber))[0][0]
    rotated_X, synced_X_tx, y, kmeans_model = signals[true_index]

    for num in vecinos:
        knn = sofa.demodulate_knn(rotated_X,y,num)
        knn_ber.append(sofa.bit_error_rate(knn,y)[0])
    knn_nei[snr[5:-2]] = knn_ber #Diferentes BER para 1 snr
    print(knn_nei)
    # print("Constelación final: ",rotated_X)
    ber[snr] = {"kmeans": kmeans_ber[true_index],
                "trad": trad_ber[true_index]}
    print(f"SNR {snr[5:]} terminado.")
    print(ber)

# %% [markdown]
# ## Gráfica Varios KNN

# %%
#snr = [18, 19, 20, 21.5, 23, 25, 27, 30, 32, 35, 40]


c=0
for i in knn_nei:
    y= []
    knnBER = knn_nei.get(i)
    tBER = np.ones((1,len(vecinos)), dtype=np.int32)*(ber.get(f"consY{i}dB").get("trad"))
    kBER = np.ones((1,len(vecinos)), dtype=np.int32)*(ber.get(f"consY{i}dB").get("kmeans"))
    
    plt.rcParams["figure.figsize"] = (20,20)
    
    ax = plt.subplot(4,3,c+1)
    
    c+=1
    ax.plot(vecinos, np.log(knnBER), marker = ">", label = "Knn")
    ax.plot(vecinos, np.log(tBER[0]), label = "trad",linestyle = 'dashed')
    #ax.plot(vecinos, np.log(kBER[0]), label = "k-means",linestyle = 'dashed')
    
    

    ax.set_xlim([1, vecinos[-1]+2])
    ax.set_xticks(vecinos)
    ax.set_yticcks()
    ax.set_xlabel("k-neigh")
    ax.set_ylabel("Log BER [dB]")
    ax.set_title(f"SNR: {i}[dB]")
    plt.grid()
    ax.legend(loc='best')
    
#plt.show()

# %% [markdown]
# ## Falsificación del modelo real

# %%
# Crear datos aleatorios
# Número de símbolos
Ns = 10000
# 16-QAM
Mod = 16
sym_tx = np.random.randint(Mod, size = Ns)

# Ahora se concatena 3 veces el array (simulando que sea infinito)
sym_tx_inf = np.concatenate((sym_tx, sym_tx))

# Ahora se tomará la longitud Ns del arreglo infinito desde un índice aleatorio
rand_index = np.random.randint(1, Ns*2 - 1)
print(f"El verdadero retraso es de {Ns - rand_index} posiciones")
sym_rx_pure = sym_tx_inf[rand_index:rand_index + Ns]

# Se modulará tanto la transmitida como la recibida
X_rx_pure = np.array([sofa.MOD_DICT[sym] for sym in sym_rx_pure])
X_tx = np.array([sofa.MOD_DICT[sym] for sym in sym_tx_inf])

snr = 24
X_ch_r, X_ch_i = sofa.add_awgn(snr, X_rx_pure)
X_ch = X_ch_r + 1j*X_ch_i

# Ahora finalmente se rotará la constelación
X_ch = X_ch*np.exp(2*1j*np.pi/2)

# Se grafica la constelación resultante
plt.scatter(X_ch.real, X_ch.imag)

# Se procede entonces a demodular (hacer el procedimiento inverso)
X = X_ch.T
kmeans_ser = []
trad_ser = []
for ph in range(4):
    # Constelación recibida rotada
    rotated_X = X_ch*np.exp(ph*1j*np.pi/2)
    # Sincronización de las señales
    rotated_X, synced_X_tx = sofa.sync_signals(rotated_X, X_tx)
    print(f"El error absoluto entre las señales sincronizadas es {np.abs(rotated_X[:5] - synced_X_tx[:5])}")
    # Se demodula la señal transmitida
    y = sofa.demodulate(synced_X_tx, sofa.MOD_DICT)
    print(y[:5])
    # Demodulación de la recibida rotada
    kmeans = sofa.demodulate_kmeans(rotated_X, sofa.MOD_DICT)
    trad = sofa.demodulate(rotated_X, sofa.MOD_DICT)
    # BER de la demodulación con respecto a la transmitida desplazada
    kmeans_ser.append(sofa.symbol_error_rate(kmeans, y))
    trad_ser.append(sofa.symbol_error_rate(trad, y))

print(kmeans_ser)
print(trad_ser)
# Probar la correlación con los datos sin demodular
# Probar girando 90° la constelación recibida
# Out:
# El verdadero retraso es de 1623 posiciones
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 38
#      36 rotated_X = X_ch*np.exp(ph*1j*np.pi/2)
#      37 # Sincronización de las señales
# ---> 38 rotated_X, synced_X_tx = sofa.sync_signals(rotated_X, X_tx)
#      39 print(f"El error absoluto entre las señales sincronizadas es {np.abs(rotated_X[:5] - synced_X_tx[:5])}")
#      40 # Se demodula la señal transmitida
#
# ValueError: too many values to unpack (expected 2)
